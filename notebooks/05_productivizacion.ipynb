# %% [markdown]
# ## Nota sobre este notebook
#
# Este notebook se dejó planificado en el diseño original del proyecto para serializar y cargar un modelo (`modelo_final.pkl`) de cara a hacer predicciones en tiempo real desde fuera de la app.
#
# Al construir la aplicación Streamlit (Fase 5) se confirmó que las tres páginas se apoyan por completo en datos ya precalculados (`dataset_maestro_electoral.csv` y `tabla_residuos.csv`, generados en las fases de preprocesamiento y residuos). No existe ningún flujo de predicción en caliente que necesite cargar un modelo, así que este notebook y la carpeta `modelos/` no se llegaron a usar.
#
# La productivización del proyecto es la aplicación desplegada en:
#
# **https://tfm-electoral-colombia-2026.streamlit.app**
#
# Ver la sección 3 del `README.md` del repositorio para el detalle de esta decisión.
