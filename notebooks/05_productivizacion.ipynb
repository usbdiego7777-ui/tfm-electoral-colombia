# %% [markdown]
# ## Nota sobre este notebook
#
# Este notebook se dejo planificado en el diseno original del proyecto para serializar y cargar un modelo (`modelo_final.pkl`) de cara a hacer predicciones en tiempo real desde fuera de la app.
#
# Al construir la aplicacion Streamlit (Fase 5) se confirmo que las tres paginas se apoyan por completo en datos ya precalculados (`dataset_maestro_electoral.csv` y `tabla_residuos.csv`, generados en las fases de preprocesamiento y residuos). No existe ningun flujo de prediccion en caliente que necesite cargar un modelo, asi que este notebook y la carpeta `modelos/` no se llegaron a usar.
#
# La productivizacion del proyecto es la aplicacion desplegada en:
#
# **https://tfm-electoral-colombia-2026.streamlit.app**
#
# Ver la seccion 3 del `README.md` del repositorio para el detalle de esta decision.
